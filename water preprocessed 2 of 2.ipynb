# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as mp
import seaborn as sb
sb.set_style('whitegrid')

# %%
data=pd.read_csv('processed.csv')
#data

# %%
data['JAN_09'].min()
# Out:
# 0.0

# %%
data['JAN_09'].max()
# Out:
# 24692.0

# %%
#data.info()

# %%
data['FEB_12'].nunique() #GETS the unique values in the column by number
# Out:
# 317

# %% [markdown]
# # new  info

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import sklearn
from sklearn.preprocessing import scale #to scale our data
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams

#to evaluate the model
import sklearn.metrics as sm
from sklearn import datasets
from sklearn.metrics import confusion_matrix, classification_report

# %%
#setting default plotting parameters for notebook
# %matplotlib inline
rcParams['figure.figsize']=200,150

# %%
consumed=pd.read_csv('processed.csv')

# %%
consumed["USER TYPE"].unique()
# Out:
# array(['H3', 'AVD', 'IRM', 'MX', 'RHC', 'H2', 'H1', 'RG', 'EQ', 'IN',
#        'IRA', 'IRB', 'CU', 'RIC'], dtype=object)

# %%
consumed["USER TYPE"].replace({
    'H3':0,
    'AVD':1,
    'IRM':2,
    'MX':3,
    'RHC':4,
    'H2':5,
    'H1':6,
    'RG':7,
    'EQ':8,
    'IN':9,
    'IRA':10,
    'IRB':11,
    'CU':12,
    'RIC':13 }, inplace=True)

# %%
consumed['CATEGORY'].unique()
# Out:
# array(['DOMESTICO MEDIO', 'DOMESTICO RESIDENCIAL', 'SOCIAL', 'COMERCIAL',
#        'DOMESTICO BAJA', 'INDUSTRIAL', 'ESPECIAL'], dtype=object)

# %%
consumed['CATEGORY'].replace({
    'DOMESTICO MEDIO':0,
    'DOMESTICO RESIDENCIAL':1,
    'SOCIAL':2,
    'COMERCIAL':3,
    'DOMESTICO BAJA':4,
    'INDUSTRIAL':5,
    'ESPECIAL':6},
inplace=True)

# %%
consumed.head(2)
# Out:
#    USER TYPE  CATEGORY  JAN_09  FEB_09  MAR_09  APR_09  MAY_09  JUN_09  \
# 0          0         0    20.0    20.0    20.0    20.0    20.0    20.0
# 1          0         0    25.2    30.0    30.0    30.0    30.0    30.0
#
#    JUL_09  AUG_09   ...    MAR_15  APR_15  MAY_15  JUN_15  JUL_15  AUG_15  \
# 0    20.0    20.0   ...       2.0     1.0     2.0     1.0     7.0     7.0
# 1    30.0    30.0   ...      11.0    13.0    16.0    14.0    15.0    16.0
#
#    SEP_15  OCT_15  NOV_15  DEC_15
# 0    42.0    27.0    22.0    21.0
# 1    13.0    17.0    17.0    11.0
#
# [2 rows x 86 columns]

# %% [markdown]
# # Standardizing now the data obtained using min max scalar

# %%
consumed['JAN_09'].min()
# Out:
# 0.0

# %%
consumed['JAN_09'].max()
# Out:
# 24692.0

# %%
#consumed

# %%
slicing = consumed.iloc[:,2:]
consumed.iloc[:,2:]= (slicing - slicing.mean()) / (slicing.max() - slicing.min())

# %%
consumed.head()
# Out:
#    USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09    APR_09    MAY_09  \
# 0          0         0 -0.001602 -0.001029 -0.000654 -0.000737 -0.000558
# 1          0         0 -0.001391 -0.000615 -0.000240 -0.000356 -0.000322
# 2          0         0 -0.001743 -0.001174 -0.000799 -0.000871 -0.000640
# 3          0         1 -0.001602 -0.001029 -0.000654 -0.000737 -0.000558
# 4          0         0 -0.001602 -0.001029 -0.000654 -0.000737 -0.000558
#
#      JUN_09    JUL_09    AUG_09    ...       MAR_15    APR_15    MAY_15  \
# 0 -0.000823 -0.000856 -0.001076    ...    -0.001662 -0.001685 -0.001936
# 1 -0.000599 -0.000648 -0.000876    ...    -0.001499 -0.001450 -0.001652
# 2 -0.000902 -0.000929 -0.001146    ...    -0.001390 -0.001313 -0.001652
# 3 -0.000823 -0.000856 -0.001076    ...    -0.001209 -0.001175 -0.001429
# 4 -0.000823 -0.000856 -0.001136    ...    -0.001354 -0.001332 -0.001612
#
#      JUN_15    JUL_15    AUG_15    SEP_15    OCT_15    NOV_15    DEC_15
# ...

# %%
consumed.describe()
# Out:
#            USER TYPE       CATEGORY        JAN_09        FEB_09        MAR_09  \
# count  161858.000000  161858.000000  1.618580e+05  1.618580e+05  1.618580e+05
# mean        2.379889       0.517633 -1.234322e-16  1.454639e-16 -1.280319e-16
# std         2.544519       0.999342  1.347469e-02  9.150236e-03  6.957660e-03
# min         0.000000       0.000000 -2.411694e-03 -1.857971e-03 -1.482938e-03
# 25%         0.000000       0.000000 -1.954055e-03 -1.402107e-03 -1.068516e-03
# 50%         0.000000       0.000000 -1.682713e-03 -1.112011e-03 -7.369787e-04
# 75%         5.000000       1.000000 -1.480218e-03 -9.462426e-04 -5.712100e-04
# max        13.000000       6.000000  9.975883e-01  9.981420e-01  9.985171e-01
#
#              APR_09        MAY_09        JUN_09        JUL_09        AUG_09  \
# count  1.618580e+05  1.618580e+05  1.618580e+05  1.618580e+05  1.618580e+05
# mean   3.186650e-16  2.017028e-17  2.454494e-17 -7.460496e-17 -6.630211e-17
# ...

# %%
#how data correlates with one another(ie one attribute correlates with the other)
consumed.corr()
# Out:
#            USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09    APR_09  \
# USER TYPE   1.000000  0.061055 -0.079294 -0.076146 -0.062756 -0.063969
# CATEGORY    0.061055  1.000000  0.311310  0.309479  0.282159  0.288210
# JAN_09     -0.079294  0.311310  1.000000  0.983169  0.956594  0.966615
# FEB_09     -0.076146  0.309479  0.983169  1.000000  0.943424  0.949463
# MAR_09     -0.062756  0.282159  0.956594  0.943424  1.000000  0.997761
# APR_09     -0.063969  0.288210  0.966615  0.949463  0.997761  1.000000
# MAY_09     -0.061210  0.277201  0.945761  0.904369  0.986080  0.988748
# JUN_09     -0.073547  0.300590  0.985372  0.948860  0.975266  0.983855
# JUL_09     -0.074110  0.301620  0.986031  0.947281  0.970362  0.979563
# AUG_09     -0.078596  0.307673  0.992845  0.956666  0.954609  0.966225
# SEP_09     -0.081000  0.310384  0.994469  0.960886  0.947284  0.959805
# OCT_09     -0.083065  0.312522  0.993874  0.961980  0.933947  0.947663
# ...

# %%
# mp.matshow(consumed.corr(), cmap="summer")
# mp.colorbar()
# mp.xticks(list(range(len(consumed.columns))), consumed.columns, rotation="vertical")
# mp.yticks(list(range(len(consumed.columns))), consumed.columns, rotation="horizontal")
# mp.show()

# %%
#splitting train set and test set by ratio 8:2
trained, tested = train_test_split(consumed, test_size=0.33)

# %%
len(trained)
# Out:
# 108444

# %%
len(tested)
# Out:
# 53414

# %%
len(consumed)*0.33
# Out:
# 53413.14

# %%
tested.to_csv('testset.csv')

# %%
trained.to_csv('trainset.csv')

# %%
train=pd.read_csv('trainset.csv')

# %%
train
# Out:
#         Unnamed: 0  USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09  \
# 0           137072          6         0 -0.001278 -0.000698 -0.000323
# 1           119192          0         0 -0.001885 -0.001278 -0.001027
# 2           108425          6         2 -0.001723 -0.001236 -0.000903
# 3           131415          0         0 -0.001480 -0.000946 -0.000737
# 4            78924          3         0 -0.001075 -0.000532 -0.000157
# 5           118613          0         0 -0.002007 -0.001526 -0.000903
# 6            90705          3         0 -0.001480 -0.000905 -0.000530
# 7           103928          5         0 -0.002128 -0.001609 -0.001193
# 8            19406          0         0 -0.001683 -0.001112 -0.000778
# 9           154298          0         0 -0.001602 -0.001029 -0.000654
# 10           74825          3         3 -0.002250 -0.001692 -0.001317
# 11           48683          5         0 -0.002331 -0.001734 -0.001359
# ...

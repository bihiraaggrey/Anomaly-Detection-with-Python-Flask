# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import sklearn
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler #scaling the data
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from sklearn.decomposition import PCA

#to evaluate the model
import sklearn.metrics as sm
from sklearn import datasets
from sklearn.metrics import confusion_matrix, classification_report

# %%
#setting default plotting parameters for notebook
# %matplotlib inline
rcParams['figure.figsize']=10,7

# %%
train=pd.read_csv('trained.csv')
len(train)
train.head(2)
# Out:
#    ID  USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09    APR_09    MAY_09  \
# 0   1          0         1 -0.002219 -0.001653 -0.001196 -0.001247 -0.000878
# 1   2          5         0 -0.002178 -0.001571 -0.001279 -0.001247 -0.000925
#
#      JUN_09    JUL_09    ...       MAR_15    APR_15    MAY_15    JUN_15  \
# 0 -0.001150 -0.001183    ...    -0.001255 -0.001089 -0.001440 -0.002066
# 1 -0.001195 -0.001204    ...    -0.001491 -0.001226 -0.001704 -0.002481
#
#      JUL_15    AUG_15    SEP_15    OCT_15    NOV_15    DEC_15
# 0 -0.003628 -0.004031 -0.009181 -0.006543 -0.001695 -0.001852
# 1 -0.003950 -0.004735 -0.010816 -0.009822 -0.002298 -0.002170
#
# [2 rows x 87 columns]

# %%
kmeans = KMeans(n_clusters=2, max_iter=700, algorithm = 'auto')
train['cluster']=kmeans.fit_predict(train[train.columns[2:]])
train
# Out:
#             ID  USER TYPE  CATEGORY        JAN_09        FEB_09    MAR_09  \
# 0            1          0         1 -2.218770e-03 -1.653421e-03 -0.001196
# 1            2          5         0 -2.178271e-03 -1.570537e-03 -0.001279
# 2            3          0         1 -2.016275e-03 -1.363326e-03 -0.000947
# 3            4          5         0 -1.651785e-03 -1.031788e-03 -0.000823
# 4            5          3         3 -2.218770e-03 -1.570537e-03 -0.001155
# 5            6          3         0 -2.218770e-03 -1.611979e-03 -0.001362
# 6            7          0         1  5.720000e-07  1.220000e-07  0.000002
# 7            8          3         0 -2.137772e-03 -1.611979e-03 -0.001155
# 8            9          5         0 -1.692284e-03 -1.073231e-03 -0.000906
# 9           10          5         0 -1.813781e-03 -1.156115e-03 -0.000409
# 10          11          0         0 -1.975776e-03 -1.529095e-03 -0.001196
# 11          12          0         0 -2.218770e-03 -1.570537e-03 -0.001320
# ...

# %%
X = np.array(train.drop(['USER TYPE'], 1).astype(float))
y = np.array(train['USER TYPE'])
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
kmeans.fit(X_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=700,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
correct = 0
for i in range(len(X_scaled)):
    predict_me = np.array(X_scaled[i].astype(float))
    predict_me = predict_me.reshape(-1, len(predict_me))
    prediction = kmeans.predict(predict_me)
    if prediction[0] == y[i]:
        correct += 1

print(correct/len(X_scaled))
# Out:
# 0.4930754777507905

# %%
train.head()
# Out:
#    ID  USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09    APR_09    MAY_09  \
# 0   1          0         1 -0.002219 -0.001653 -0.001196 -0.001247 -0.000878
# 1   2          5         0 -0.002178 -0.001571 -0.001279 -0.001247 -0.000925
# 2   3          0         1 -0.002016 -0.001363 -0.000947 -0.001018 -0.000737
# 3   4          5         0 -0.001652 -0.001032 -0.000823 -0.000904 -0.000525
# 4   5          3         3 -0.002219 -0.001571 -0.001155 -0.001208 -0.000855
#
#      JUN_09    JUL_09   ...       APR_15    MAY_15    JUN_15    JUL_15  \
# 0 -0.001150 -0.001183   ...    -0.001089 -0.001440 -0.002066 -0.003628
# 1 -0.001195 -0.001204   ...    -0.001226 -0.001704 -0.002481 -0.003950
# 2 -0.001015 -0.001038   ...    -0.001521 -0.001704 -0.002705 -0.004353
# 3 -0.000925 -0.000954   ...    -0.001403 -0.001744 -0.002545 -0.004031
# 4 -0.001127 -0.001142   ...    -0.001246 -0.001501 -0.002194 -0.003869
#
#      AUG_15    SEP_15    OCT_15    NOV_15    DEC_15  cluster
# ...

# %%
import pandas as pad
train.to_csv('dataprocessed.csv')
dataset=pad.read_csv('dataprocessed.csv')
dataset.head()
# Out:
#    Unnamed: 0  ID  USER TYPE  CATEGORY    JAN_09    FEB_09    MAR_09  \
# 0           0   1          0         1 -0.002219 -0.001653 -0.001196
# 1           1   2          5         0 -0.002178 -0.001571 -0.001279
# 2           2   3          0         1 -0.002016 -0.001363 -0.000947
# 3           3   4          5         0 -0.001652 -0.001032 -0.000823
# 4           4   5          3         3 -0.002219 -0.001571 -0.001155
#
#      APR_09    MAY_09    JUN_09   ...       APR_15    MAY_15    JUN_15  \
# 0 -0.001247 -0.000878 -0.001150   ...    -0.001089 -0.001440 -0.002066
# 1 -0.001247 -0.000925 -0.001195   ...    -0.001226 -0.001704 -0.002481
# 2 -0.001018 -0.000737 -0.001015   ...    -0.001521 -0.001704 -0.002705
# 3 -0.000904 -0.000525 -0.000925   ...    -0.001403 -0.001744 -0.002545
# 4 -0.001208 -0.000855 -0.001127   ...    -0.001246 -0.001501 -0.002194
#
#      JUL_15    AUG_15    SEP_15    OCT_15    NOV_15    DEC_15  cluster
# ...
